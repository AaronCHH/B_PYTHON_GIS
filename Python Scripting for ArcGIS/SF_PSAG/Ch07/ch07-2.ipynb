# %%
# %load pt7_2_1.py
import arcpy

fc = "./DATA.gdb/roads"
cursor = arcpy.da.SearchCursor(fc, ["NAME"])

for row in cursor:
	print "Streetname = {0}".format(row[0])
# Out:
# Streetname =
# Streetname = State Route 131
# Streetname =
# Streetname = State Route 3
# Streetname = State Route 3
# Streetname =
# Streetname = State Route 3
# Streetname = State Route 411
# Streetname = State Route 3
# Streetname = State Route 3
# Streetname = State Route 5, State Route 786
# Streetname = State Route 3
# Streetname = State Route 4
# Streetname = State Route 3
# Streetname =
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 2
# Streetname = State Route 2
# Streetname = State Route 1
# Streetname = State Route 4
# Streetname = State Route 1
# Streetname = State Route 1, State Route 4
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 9
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 97
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 3
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 924
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 2
# Streetname = State Route 2
# Streetname = State Route 2
# Streetname =
# Streetname = State Route 6
# Streetname =
# Streetname =
# Streetname = State Route 6
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 5
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 5
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 5
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 10
# Streetname =
# Streetname =
# Streetname = State Route 10
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname =
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname =
# Streetname =
# Streetname = State Route 4
# Streetname = State Route 4
# Streetname =
# Streetname = State Route 10
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 6
# Streetname = State Route 6
# Streetname = State Route 2
# Streetname = State Route 2
# Streetname = State Route 2
# Streetname = State Route 2
# Streetname = State Route 2, State Route 65
# Streetname = State Route 2, State Route 65
# Streetname =
# Streetname = State Route 3
# Streetname =
# Streetname =
# Streetname = State Route 7, State Route 937
# Streetname =
# Streetname =
# Streetname = State Route 7, State Route 937
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 2
# Streetname =
# Streetname = State Route 3
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 2
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 1
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 2
# Streetname =
# Streetname = State Route 8
# Streetname =
# Streetname =
# Streetname = State Route 7
# Streetname =
# Streetname = State Route 1
# Streetname = State Route 4
# Streetname =
# Streetname = State Route 3
# Streetname =
# Streetname =
# Streetname = State Route 3
# Streetname = State Route 7, State Route 937
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =

# %%
# %load pt7_2_2.py
import arcpy

fc = "./DATA.gdb/roads"
# cursor = arcpy.da.SearchCursor(fc, ["NAME"])
with arcpy.da.SearchCursor(fc, ["NAME"]) as cursor:
	for row in cursor:
		print "Streetname = {0}".format(row[0])
# Out:
# Streetname =
# Streetname = State Route 131
# Streetname =
# Streetname = State Route 3
# Streetname = State Route 3
# Streetname =
# Streetname = State Route 3
# Streetname = State Route 411
# Streetname = State Route 3
# Streetname = State Route 3
# Streetname = State Route 5, State Route 786
# Streetname = State Route 3
# Streetname = State Route 4
# Streetname = State Route 3
# Streetname =
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 2
# Streetname = State Route 2
# Streetname = State Route 1
# Streetname = State Route 4
# Streetname = State Route 1
# Streetname = State Route 1, State Route 4
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 9
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 97
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 3
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 924
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 2
# Streetname = State Route 2
# Streetname = State Route 2
# Streetname =
# Streetname = State Route 6
# Streetname =
# Streetname =
# Streetname = State Route 6
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 5
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 5
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 5
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 10
# Streetname =
# Streetname =
# Streetname = State Route 10
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname =
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname =
# Streetname =
# Streetname = State Route 4
# Streetname = State Route 4
# Streetname =
# Streetname = State Route 10
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 6
# Streetname = State Route 6
# Streetname = State Route 2
# Streetname = State Route 2
# Streetname = State Route 2
# Streetname = State Route 2
# Streetname = State Route 2, State Route 65
# Streetname = State Route 2, State Route 65
# Streetname =
# Streetname = State Route 3
# Streetname =
# Streetname =
# Streetname = State Route 7, State Route 937
# Streetname =
# Streetname =
# Streetname = State Route 7, State Route 937
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 2
# Streetname =
# Streetname = State Route 3
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 1
# Streetname = State Route 2
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 1
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname = State Route 2
# Streetname =
# Streetname = State Route 8
# Streetname =
# Streetname =
# Streetname = State Route 7
# Streetname =
# Streetname = State Route 1
# Streetname = State Route 4
# Streetname =
# Streetname = State Route 3
# Streetname =
# Streetname =
# Streetname = State Route 3
# Streetname = State Route 7, State Route 937
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
# Streetname =
